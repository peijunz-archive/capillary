# %%
from capillary import edge, fitting, display

# %%
from importlib import reload
reload(edge);
reload(fitting);
reload(display);

# %%
x1, x2, pos, neg, fp, fn = fitting.adaptive_fit(edge.G[6], 70)
#print(pos, neg)
#= split(pts)
#x1, x2 = optimize_fit(pos), optimize_fit(neg)
display.show_hull(x1, 1)
display.show_hull(x2, 1)
display.show_split(pos, neg)
plot([x1[0], x2[0]], [x1[1], x2[1]], 'o-')
axis('equal');
print(x1[2], x2[2])
# Out:
# (2.8498174069742253, 2.647655775873288)
# 30.0 30.0
