# %% [markdown]
# # Gallery

# %%
from capillary import edge, fitting, analyse, display
i=1
df=analyse.analyse_raw(i)

# %%
df.loc[df['time']<0].plot('time', 'rho');
title(r'$\rho$ for video {}'.format(i))
grid();

# %%
df.loc[df['time']<0].plot('time', 'theta21');
title(r'$\theta_{{21}}$ for video {}'.format(i))
grid();

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
    
fig.suptitle(r'$\theta$ for video {}'.format(i))

axes[0].set_title(r'$t\leq -1$s')
df.loc[df['time']<=-1].plot('time', ['theta1', 'theta2'], ax=axes[0]);
axes[0].grid();

axes[1].set_title(r'$t\geq -1$s')
df.loc[df['time']>=-1].plot('time', ['theta1', 'theta2'], ax=axes[1]);
axes[1].grid();

# %%
fig, axes = plt.subplots(1, 2, sharey=True)
    
fig.suptitle(r'$\phi$ for video {}'.format(i))

axes[0].set_title(r'$t\leq -1$s')
df.loc[df['time']<=-1].plot('time', ['phi1', 'phi2'], ax=axes[0]);
axes[0].grid();

axes[1].set_title(r'$t\geq -1$s')
df.loc[df['time']>=-1].plot('time', ['phi1', 'phi2'], ax=axes[1]);
axes[1].grid();

# %%
for i in range(2, 8):
    df=analyse.analyse_raw(i)

    df.loc[df['time']<0].plot('time', 'rho');
    title(r'$\rho$ for video {}'.format(i))
    grid();
    
    fig, axes = plt.subplots(1, 2, sharey=True)
    
    fig.suptitle(r'$\theta$ for video {}'.format(i))

    axes[0].set_title(r'$t\leq -1$s')
    df.loc[df['time']<=-1].plot('time', ['theta1', 'theta2'], ax=axes[0]);
    axes[0].grid();

    axes[1].set_title(r'$t\geq -1$s')
    df.loc[df['time']>=-1].plot('time', ['theta1', 'theta2'], ax=axes[1]);
    axes[1].grid();
