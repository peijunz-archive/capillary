# %% [markdown]
# # Measure

# %%
subplot('221')
plot(s[0]-pi, 'o', markersize=1, label=r"$\theta-\pi$")
legend(loc='upper left')
ylim(-0.1, +0.1)
#title('angle with respect to pi')
subplot('222')
plot(s[1], 'o', markersize=1, label=r"$R$")
legend(loc='lower left')
#title('Displacement');
subplot('212')
plot(s[2], 'o', markersize=1, label=r"$\phi_1$");
plot(s[3], 'o', markersize=1, label=r"$\phi_2$");
legend(loc='upper left')
savefig('res.pdf')
