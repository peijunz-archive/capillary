# %%
from capillary import edge, fitting, display

# %%
from importlib import reload
reload(edge);

# %%
rcParams['figure.figsize'] = 5, 5

# %%
im=edge.R[1](10);
#figure(figsize= (20,20));

# %%
imshow(im);

# %%
pts=edge.G[2](1196)
x, y = pts

# %%
display.show_frame(pts)
axis('equal');
savefig('a.pdf')
# Out:
# /home/zpj/code/capillary/doc/capillary/fitting.py:40: UserWarning: Particles are too close, separation may fail!
#   warnings.warn("Particles are too close, separation may fail!")

# %% [markdown]
# # How to make further enhancement to split particles
