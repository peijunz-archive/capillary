# %%
from capillary import edge, fitting, display, analyse

# %%
from importlib import reload
reload(analyse);

# %%
rho, theta, t1, t2=analyse.analyse(edge.get, range(1, 74))

# %%
plot((theta-pi)*180/pi, 'o', markersize=3, label=r"$\theta-180^\circ$")
ylim(-2, 2)
xlabel('Frame')
ylabel(r'$\theta-180/^\circ$')
title('Revolution Angle')
legend(loc='upper left');
savefig('figures/angle.pdf');

# %%
plot(rho, 'o-', markersize=2, label=r"$R$")
title('Displacement')
xlabel('Frame')
ylabel(r'$\rho/$px')
savefig('figures/displacement.pdf');

# %%
plot(t1, 'o', markersize=1, label=r"$\phi_1$");
plot(t2, 'o', markersize=1, label=r"$\phi_2$");
plot((t1+t2)/2, '-', markersize=1, label=r"$(\phi_1+\phi_2)/2$");
legend(loc='upper left');
xlabel('Frame')
ylabel(r'$\phi/$rad')
title('Orientation')
savefig('figures/orientation.pdf');
