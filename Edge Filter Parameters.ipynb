# %%
from capillary import edge, fitting, display

# %%
from importlib import reload
reload(edge);
reload(fitting);
reload(display);

# %%
x1, x2, pos, neg, fp, fn = fitting.adaptive_fit(3, 1135, lv=6)
display.show_hull(x1, 1)
display.show_hull(x2, 1)
display.show_split(pos, neg)
plot([x1[0], x2[0]], [x1[1], x2[1]], 'o-')
axis('equal');
# Out:
# (1.7774801005734069, 1.7186470157111506)

# %%
import matplotlib.pyplot as plt
