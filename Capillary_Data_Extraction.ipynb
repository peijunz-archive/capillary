# %%
from capillary import edge, fitting

# %%
from importlib import reload
reload(fitting);
reload(edge);

# %%
from capillary import edge, fitting
for i in range(73):
    clf()
    pts=edge.get(i+1)
    pos, neg=fitting.split(pts)
    fitting.show_hull(pos)
    fitting.show_hull(neg)
    fitting.show_split(pts)
    fitting.show_displace(pts)
    #grid();
    axis('square');
    xlim(0, 284)
    ylim(0, 284)
    savefig('processed/output_%04d_processed.svg'%(i+1),
            bbox_inches='tight',
           );
# Out:
# /home/zpj/code/capillary/capillary/fitting.py:39: UserWarning: Particles are too close, separation may fail!
#   warnings.warn("Particles are too close, separation may fail!")
