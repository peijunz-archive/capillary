# %%
from capillary import edge, fitting, display

# %%
from importlib import reload
reload(edge);
reload(fitting);
reload(display);

# %%
#rcParams['figure.figsize'] = 5, 5

# %%
im=edge.R[1](10);
#figure(figsize= (20,20));

# %%
#imshow(im);

# %%
pts=edge.G[2](1196)
x, y = pts

# %%
display.show_frame(pts)
axis('equal');
savefig('a.pdf')

# %% [markdown]
# # How to make further enhancement to split particles

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-270-cadb7b625fa2> in <module>()
# ----> 1 x,y=1,2,3
#
# ValueError: too many values to unpack (expected 2)

# %%
x=1<2

# %%
x
# Out:
# False

# %%
([1,2,3,4])[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-16db84b275bc> in <module>()
# ----> 1 ([1,2,3,4])[array([1,2,3])>array([3,2,1])]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
a=array([1,2,3])>array([3,2,1])

# %%
a.nonzero()
# Out:
# (array([2]),)

# %%
(~a).nonzero()
# Out:
# (array([0, 1]),)

# %%
a=arange(10)

# %%
a.shape
# Out:
# (10,)
